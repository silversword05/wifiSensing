# %%
from numpy import array
from pandas import read_csv
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pandas as pd
from autogluon.tabular import TabularPredictor as task
import numpy as np
import copy
from sklearn.preprocessing import RobustScaler

# %%
cols = [i for i in range(1,209)]
cols.extend(["time", "ground_truth"])
df = pd.DataFrame(columns = cols)

# %%
skip = [11, 14]
for i in range(10,19):
    if i not in skip:
        df = pd.concat([df, read_csv("data/data_"+ str(i)+ "/final_dataset2.csv", names = cols)])
#subs_df["time"] = final_df.time
df.drop(columns = "time", inplace = True)
df.drop(columns = list(range(53, 209)), inplace = True)
df
# Out:
#              1          2         3         4          5          6  \
# 0     6.994544   6.994544  6.994544  6.994544   8.992985   8.992985
# 1     7.015450   6.013243  6.013243  6.013243  10.022071  10.022071
# 2     7.030526   6.026165  6.026165  6.026165  10.043608  10.043608
# 3     7.069335   7.069335  7.069335  7.069335   9.089145  12.118860
# 4     7.251873   7.251873  7.251873  7.251873  20.719637  12.431782
# ..         ...        ...       ...       ...        ...        ...
# 220  10.994952  24.988527  7.996329  7.996329   8.995870   8.995870
# 221   8.019469   6.014602  8.019469  8.019469   8.019469   8.019469
# 222   7.992521  24.976629  6.993456  7.992521   7.992521   7.992521
# 223   8.012110   6.009082  6.009082  6.009082   6.009082   7.010596
# 224   6.995417   6.995417  6.995417  6.995417   6.995417   6.995417
#
#              7          8          9        10  ...         44         45  \
# 0     8.992985   8.992985   8.992985  7.993764  ...   6.994544   7.993764
# 1    10.022071  10.022071  10.022071  9.019864  ...   7.015450   7.015450
# 2    10.043608  10.043608  10.043608  9.039248  ...   7.030526   7.030526
# 3    12.118860  12.118860   9.089145  9.089145  ...   6.059430   6.059430
# 4    12.431782  11.395800  11.395800  6.215891  ...  11.395800  11.395800
# ..         ...        ...        ...       ...  ...        ...        ...
# 220   9.995411  10.994952  10.994952  9.995411  ...   6.996788   9.995411
# 221   8.019469   8.019469   9.021903  6.014602  ...   6.014602   6.014602
# 222   7.992521   7.992521   7.992521  6.993456  ...   6.993456   6.993456
# 223   7.010596   7.010596   8.012110  6.009082  ...   6.009082   6.009082
# 224   6.995417   6.995417   6.995417  6.995417  ...   6.995417  11.992143
#
#             46         47         48         49         50         51  \
# 0     7.993764   7.993764   7.993764   6.994544   6.994544   6.994544
# 1     7.015450   8.017657   8.017657   7.015450   7.015450   7.015450
# 2     7.030526   8.034887   8.034887   7.030526  15.065413   8.034887
# 3    11.108955  11.108955  11.108955  12.118860  12.118860  12.118860
# 4    11.395800  11.395800  11.395800  11.395800  12.431782  12.431782
# ..         ...        ...        ...        ...        ...        ...
# 220  14.993116  13.993575  12.994034  11.994493  11.994493  12.994034
# 221  14.034071  14.034071  12.029204  12.029204  12.029204  12.029204
# 222   7.992521  14.985977   7.992521   7.992521   7.992521   7.992521
# 223  16.024219  16.024219   8.012110   8.012110   8.012110   8.012110
# 224  15.989524  16.988869   7.994762   7.994762   7.994762   8.994107
#
#             52  ground_truth
# 0    12.989867      7.835287
# 1     6.013243      8.280366
# 2    14.061052      8.738751
# 3     6.059430      9.179094
# 4    17.611691      9.624450
# ..         ...           ...
# 220  11.994493     16.226451
# 221  12.029204     16.263134
    metric = 'root_mean_squared_error'
    label_column = "ground_truth"
    print("train....")
    predictor = task(label=label_column, problem_type='regression', eval_metric=metric, path = "./autoresults10").fit(train_data=train_dataset, presets = "best_quality",  verbosity = 2, time_limit = 3*60, auto_stack=True)
    return predictor
new_predict = fit_model(df_scale)
# Out:
# Presets specified: ['best_quality']
# Beginning AutoGluon training ... Time limit = 180s
# AutoGluon will save models to "./autoresults10/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1575
# Train Data Columns: 52
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    2888.02 MB
# 	Train Data (Original)  Memory Usage: 0.66 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# train....
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 52 | ['1', '2', '3', '4', '5', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 52 | ['1', '2', '3', '4', '5', ...]
# 	0.2s = Fit runtime
# 	52 features in original data used to generate 52 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.66 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.3s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 119.77s of the 179.69s of remaining time.
# 	-0.5394	 = Validation score   (root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 119.12s of the 179.04s of remaining time.
# 	-0.521	 = Validation score   (root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 118.76s of the 178.68s of remaining time.
# /u/a/m/amondal5/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 8. Best iteration is:
# 	[8]	train_set's rmse: 0.630787	valid_set's rmse: 0.667949
# /u/a/m/amondal5/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 8. Best iteration is:
# 	[8]	train_set's rmse: 0.628511	valid_set's rmse: 0.693866
# /u/a/m/amondal5/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 11. Best iteration is:
# 	[11]	train_set's rmse: 0.615365	valid_set's rmse: 0.595564
# /u/a/m/amondal5/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 10. Best iteration is:
# 	[10]	train_set's rmse: 0.621459	valid_set's rmse: 0.559023
# /u/a/m/amondal5/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 7. Best iteration is:
# 	[7]	train_set's rmse: 0.628771	valid_set's rmse: 0.72628
# /u/a/m/amondal5/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 9. Best iteration is:
# 	[9]	train_set's rmse: 0.624596	valid_set's rmse: 0.626261
# /u/a/m/amondal5/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 11. Best iteration is:
# 	[11]	train_set's rmse: 0.606802	valid_set's rmse: 0.669876
# /u/a/m/amondal5/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 16. Best iteration is:
# 	[16]	train_set's rmse: 0.583215	valid_set's rmse: 0.543722
# /u/a/m/amondal5/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 13. Best iteration is:
# 	[13]	train_set's rmse: 0.590308	valid_set's rmse: 0.665596
# /u/a/m/amondal5/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 9. Best iteration is:
# 	[9]	train_set's rmse: 0.622923	valid_set's rmse: 0.645925
# 	-0.6418	 = Validation score   (root_mean_squared_error)
# 	115.31s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2.51s of the 62.43s of remaining time.
# /u/a/m/amondal5/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 1. Best iteration is:
# 	[1]	train_set's rmse: 0.681931	valid_set's rmse: 0.707298
# 	Time limit exceeded... Skipping LightGBM_BAG_L1.
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 0.89s of the 60.81s of remaining time.
# 	-0.4522	 = Validation score   (root_mean_squared_error)
# 	25.3s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 179.7s of the 28.74s of remaining time.
# 	-0.4382	 = Validation score   (root_mean_squared_error)
# 	0.47s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 28.1s of the 28.09s of remaining time.
# /u/a/m/amondal5/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 1. Best iteration is:
# 	[1]	train_set's rmse: 0.674663	valid_set's rmse: 0.720363
# /u/a/m/amondal5/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 1. Best iteration is:
# 	[1]	train_set's rmse: 0.664908	valid_set's rmse: 0.793246
# 	Time limit exceeded... Skipping LightGBMXT_BAG_L2.
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 21.69s of the 21.68s of remaining time.
# /u/a/m/amondal5/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 1. Best iteration is:
# 	[1]	train_set's rmse: 0.669781	valid_set's rmse: 0.715264
# /u/a/m/amondal5/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 1. Best iteration is:
# 	[1]	train_set's rmse: 0.661258	valid_set's rmse: 0.790342
# /u/a/m/amondal5/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	Ran out of time, early stopping on iteration 2. Best iteration is:
# 	[2]	train_set's rmse: 0.658492	valid_set's rmse: 0.56211
# 	Time limit exceeded... Skipping LightGBM_BAG_L2.
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 14.3s of the 14.27s of remaining time.
# 	-0.3604	 = Validation score   (root_mean_squared_error)
# 	21.07s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 179.68s of the -14.16s of remaining time.
# 	-0.3604	 = Validation score   (root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 194.51s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("./autoresults10/")

# %%
new_predict = task.load("autoresults/")
new_predict.leaderboard()
# Out:
#                     model  score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0     WeightedEnsemble_L2  -0.378846       0.546329   10.617290                0.000399           0.357529            2       True          5
# 1  RandomForestMSE_BAG_L1  -0.388960       0.329139   10.238779                0.329139          10.238779            1       True          4
# 2   KNeighborsDist_BAG_L1  -0.468409       0.216791    0.020982                0.216791           0.020982            1       True          2
# 3   KNeighborsUnif_BAG_L1  -0.485220       0.206995    0.031978                0.206995           0.031978            1       True          1
# 4       LightGBMXT_BAG_L2  -0.543648       1.100820  172.630946                0.181577          46.754575            2       True          6
# 5     WeightedEnsemble_L3  -0.543648       1.101295  172.632837                0.000475           0.001891            3       True          7
# 6       LightGBMXT_BAG_L1  -0.545817       0.166318  115.584633                0.166318         115.584633            1       True          3
#                     model  score_val  pred_time_val    fit_time  \
# 0     WeightedEnsemble_L2  -0.378846       0.546329   10.617290
# 1  RandomForestMSE_BAG_L1  -0.388960       0.329139   10.238779
# 2   KNeighborsDist_BAG_L1  -0.468409       0.216791    0.020982
# 3   KNeighborsUnif_BAG_L1  -0.485220       0.206995    0.031978
# 4       LightGBMXT_BAG_L2  -0.543648       1.100820  172.630946
# 5     WeightedEnsemble_L3  -0.543648       1.101295  172.632837
# 6       LightGBMXT_BAG_L1  -0.545817       0.166318  115.584633
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                0.000399           0.357529            2       True
# 1                0.329139          10.238779            1       True
# 2                0.216791           0.020982            1       True
# 3                0.206995           0.031978            1       True
# 4                0.181577          46.754575            2       True
# 5                0.000475           0.001891            3       True
# 6                0.166318         115.584633            1       True
#
#    fit_order
# 0          5
# 1          4
# 2          2
# 3          1
# 4          6
# 5          7
# 6          3

# %%
def forecast(predictor, input_x, model = None ):
    input_x_no_label = input_x.drop(columns = ["ground_truth"])
    prediction_sequence = predictor.predict(input_x_no_label, model = model).tolist()
    return prediction_sequence

# %%
cols = [i for i in range(1,209)]
cols.extend(["time", "ground_truth"])
test_df = pd.DataFrame(columns = cols)

for i in skip:
    test_df = pd.concat([test_df, read_csv("data/data_"+ str(i)+ "/final_dataset2.csv", names = cols)])

test_df.drop(columns = list(range(53, 209)), inplace = True)
    
test_df_time = test_df["time"].to_numpy()
actual_ground_truth = test_df["ground_truth"].to_numpy()
print(type(test_df_time), len(actual_ground_truth))
test_df.drop(columns = "time", inplace = True)
test_df
# ..         ...        ...        ...        ...        ...        ...
# 445   6.987660   6.987660   6.987660   6.987660   6.987660   6.987660
# 446   6.999209   6.999209   6.999209   6.999209   6.999209   6.999209
# 447   6.000019   6.000019   6.000019   6.000019   6.000019   6.000019
# 448   6.010948   6.010948   6.010948   6.010948   6.010948   6.010948
# 449   6.991558   6.991558   6.991558   6.991558   6.991558   6.991558
#
#              7          8          9         10  ...         44         45  \
# 0     6.246758   6.246758  17.699148  18.740275  ...   8.329011   6.246758
# 1    20.979626  20.979626  20.979626  20.979626  ...   8.991268   8.991268
# 2    21.984124  21.984124  20.984846  21.984124  ...   9.992784   9.992784
# 3    24.405172  18.303879  18.303879  18.303879  ...  10.168822  11.185704
# 4    22.027432  22.027432  18.022444  22.027432  ...  10.012469  11.013716
# ..         ...        ...        ...        ...  ...        ...        ...
# 445   6.987660   6.987660   6.987660   7.985898  ...   6.987660   6.987660
# 446   6.999209   6.999209   6.999209   7.999096  ...   6.999209   6.999209
# 447   6.000019   7.000022   6.000019  11.000035  ...   6.000019   6.000019
# 448   6.010948   6.010948   6.010948  11.020072  ...   6.010948   6.010948
# 449   6.991558   6.991558   6.991558  10.986734  ...   9.987940   8.989146
#
#             46         47         48         49         50         51  \
# 0     7.287885   8.329011   8.329011  14.575769  14.575769  14.575769
# 1     8.991268   8.991268   8.991268   9.990298  12.987388  12.987388
# 2     9.992784   9.992784  10.992062  10.992062  10.992062  11.991340
# 3    11.185704  11.185704  11.185704  11.185704  11.185704  11.185704
# 4    11.013716  11.013716  12.014963  12.014963  12.014963  12.014963
# ..         ...        ...        ...        ...        ...        ...
# 445   6.987660   6.987660   6.987660   6.987660   6.987660   6.987660
# 446   6.999209   6.999209   6.999209   6.999209   6.999209   6.999209
# 447   6.000019   6.000019   6.000019   6.000019   6.000019   6.000019
# 448   6.010948   6.010948   6.010948   6.010948   6.010948   6.010948
# 449   8.989146   6.991558   6.991558   6.991558   6.991558   6.991558
#
#             52  ground_truth
# 0    15.616895      2.019093
# 1    12.987388      2.743669
# 2    12.990619      3.285214
# 3    12.202586      3.846166
# 4    12.014963      4.227430
# ..         ...           ...
# 445   6.987660      8.283920
# 446   6.999209      8.181399
# 447   6.000019      8.080930
# 448   6.010948      7.982436
# 449   6.991558      7.888536
#
# [450 rows x 53 columns]

# %%
plt.plot(df_unscale_test_orig["ground_truth"].to_numpy(), label = "transformed")
plt.plot(test_df["ground_truth"].to_numpy(), label = "actual")
plt.legend()

# %%
output = forecast(new_predict, df_scale_test)
#output

# %%
print(output[:2])
# Out:
# [-0.2811553180217743, 0.062111593782901764]

# %%
df_scale_test["ground_truth"] = output
df_scale_test
# Out:
#             1         2         3         4         5         6         7  \
# 0    0.057044  0.043534  0.185200  0.185501 -0.534547 -0.495260 -0.417860
# 1    0.137457  0.241024  0.415621  0.411185  1.573081  1.876587  1.805381
# 2   -0.418188 -0.384272 -0.313940 -0.303377 -0.427514 -0.374808  1.956963
# 3   -0.542501 -0.496180 -0.444508 -0.431260 -0.555357 -0.518678  2.322307
# 4    0.001569 -0.006405  0.126934 -0.014846 -0.139074  2.045273  1.963498
# 448   6.010948   6.010948   6.010948   6.010948   6.010948   6.010948
# 449   6.991558   6.991558   6.991558   6.991558   6.991558   6.991558
#
#              7          8          9         10  ...         44         45  \
# 0     6.246758   6.246758  17.699148  18.740275  ...   8.329011   6.246758
# 1    20.979626  20.979626  20.979626  20.979626  ...   8.991268   8.991268
# 2    21.984124  21.984124  20.984846  21.984124  ...   9.992784   9.992784
# 3    24.405172  18.303879  18.303879  18.303879  ...  10.168822  11.185704
# 4    22.027432  22.027432  18.022444  22.027432  ...  10.012469  11.013716
# ..         ...        ...        ...        ...  ...        ...        ...
# 445   6.987660   6.987660   6.987660   7.985898  ...   6.987660   6.987660
# 446   6.999209   6.999209   6.999209   7.999096  ...   6.999209   6.999209
# 447   6.000019   7.000022   6.000019  11.000035  ...   6.000019   6.000019
# 448   6.010948   6.010948   6.010948  11.020072  ...   6.010948   6.010948
# 449   6.991558   6.991558   6.991558  10.986734  ...   9.987940   8.989146
#
#             46         47         48         49         50         51  \
# 0     7.287885   8.329011   8.329011  14.575769  14.575769  14.575769
# 1     8.991268   8.991268   8.991268   9.990298  12.987388  12.987388
# 2     9.992784   9.992784  10.992062  10.992062  10.992062  11.991340
# 3    11.185704  11.185704  11.185704  11.185704  11.185704  11.185704
# 4    11.013716  11.013716  12.014963  12.014963  12.014963  12.014963
# ..         ...        ...        ...        ...        ...        ...
# 445   6.987660   6.987660   6.987660   6.987660   6.987660   6.987660
# 446   6.999209   6.999209   6.999209   6.999209   6.999209   6.999209
# 447   6.000019   6.000019   6.000019   6.000019   6.000019   6.000019
# 448   6.010948   6.010948   6.010948   6.010948   6.010948   6.010948
# 449   8.989146   6.991558   6.991558   6.991558   6.991558   6.991558
#
#             52  ground_truth
# 0    15.616895     12.119402
# 1    12.987388     14.383659
# 2    12.990619     10.731242
# 3    12.202586     11.365055
# 4    12.014963     11.427403
# ..         ...           ...
# 445   6.987660     10.126943
# 446   6.999209      9.963236
# 447   6.000019     10.313517
# 448   6.010948     10.774670
# 449   6.991558     10.640674
#
# [450 rows x 53 columns]

# %%
plt.plot(df_unscale_test["ground_truth"].to_numpy()[50:], label = "estimate")
plt.plot(df_unscale_test_orig["ground_truth"].to_numpy()[50:], label = "actual")
plt.legend()

# %%
from scipy.signal import savgol_filter
smooth_estimate = savgol_filter(df_unscale_test["ground_truth"][50:], 21, 6) # window size 51, polynomial order 3
smooth_ground = savgol_filter(df_unscale_test_orig["ground_truth"][50:], 21, 6) # window size 51, polynomial order 3
plt.plot(smooth_estimate, label = "estimate")
plt.plot(smooth_ground, label = "actual")
plt.legend()

# %%
test_sam = new_predict.leaderboard(data = df_scale_test_copy)
# Out:
#                     model  score_test  score_val  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       LightGBMXT_BAG_L1   -0.693238  -0.545817        0.776597       0.166318  115.584633                 0.776597                0.166318         115.584633            1       True          3
# 1       LightGBMXT_BAG_L2   -0.696588  -0.543648        1.399398       1.100820  172.630946                 0.279830                0.181577          46.754575            2       True          6
# 2     WeightedEnsemble_L3   -0.696588  -0.543648        1.400951       1.101295  172.632837                 0.001553                0.000475           0.001891            3       True          7
# 3  RandomForestMSE_BAG_L1   -0.697935  -0.388960        0.176044       0.329139   10.238779                 0.176044                0.329139          10.238779            1       True          4
# 4     WeightedEnsemble_L2   -0.705676  -0.378846        0.251881       0.546329   10.617290                 0.002373                0.000399           0.357529            2       True          5
# 5   KNeighborsDist_BAG_L1   -0.847370  -0.468409        0.073464       0.216791    0.020982                 0.073464                0.216791           0.020982            1       True          2
# 6   KNeighborsUnif_BAG_L1   -0.847880  -0.485220        0.093462       0.206995    0.031978                 0.093462                0.206995           0.031978            1       True          1

# %%
new_predict.get_model_names()
# Out:
# ['KNeighborsUnif_BAG_L1',
#  'KNeighborsDist_BAG_L1',
#  'LightGBMXT_BAG_L1',
#  'RandomForestMSE_BAG_L1',
#  'WeightedEnsemble_L2',
#  'LightGBMXT_BAG_L2',
#  'WeightedEnsemble_L3']

# %%
test_sam["model"].to_list()
# Out:
# ['LightGBMXT_BAG_L1',
#  'LightGBMXT_BAG_L2',
#  'WeightedEnsemble_L3',
#  'RandomForestMSE_BAG_L1',
#  'WeightedEnsemble_L2',
#  'KNeighborsDist_BAG_L1',
#  'KNeighborsUnif_BAG_L1']

# %%
#predictor

# %%
cols = [i for i in range(1,209)]
cols.extend(["time", "ground_truth"])

from matplotlib.pyplot import figure
figure(figsize=(16, 9), dpi=80)

model_res = dict()

for i in skip:
    test_df = pd.DataFrame(columns = cols)
    test_df = pd.concat([test_df, read_csv("data/data_"+ str(i)+ "/final_dataset2.csv", names = cols)])
    
    test_df_time = test_df["time"].to_list()
    test_df_time = test_df_time[50:]
    
    test_df.drop(columns = list(range(53, 209)), inplace = True)
    test_df.drop(columns = "time", inplace = True)
    
    scale_test = scaler.transform(test_df)
    df_scale_test = pd.DataFrame(scale_test, columns = test_df.columns)
    
    df_scale_test_copy = df_scale_test.copy()
    unscale_test_orig = scaler.inverse_transform(df_scale_test_copy)
    df_unscale_test_orig = pd.DataFrame(unscale_test_orig, columns = df_scale_test_copy.columns)
    
    models = new_predict.leaderboard(data = df_scale_test_copy)
    print(models)
    models = models["model"].to_list()
    
    for modelName in models:
        output = forecast(new_predict, df_scale_test, modelName)
        df_scale_test["ground_truth"] = output
        
        unscale_test = scaler.inverse_transform(df_scale_test)
        df_unscale_test = pd.DataFrame(unscale_test, columns = df_scale_test.columns)
        
        smooth_estimate = savgol_filter(df_unscale_test["ground_truth"][50:], 21, 6) # window size 51, polynomial order 3
        smooth_ground = savgol_filter(df_unscale_test_orig["ground_truth"][50:], 21, 6) # window size 51, polynomial order 3
        print("data", i, "model", modelName)
        
        if i not in model_res:
            model_res[i] = dict()
            
        evaluate_data = new_predict.evaluate(df_scale_test_copy, model = modelName)
        evaluate_data["name"] = modelName
        model_res[i][modelName] = evaluate_data
        
        print(model_res[i][modelName])
        figure(figsize=(16, 9), dpi=80)
        plt.plot(test_df_time, smooth_estimate, label = "estimate")
        plt.plot(test_df_time, smooth_ground, label = "actual")
        plt.xlabel("Time Elapsed (s)")
        plt.ylabel("Breathing Rate")
        plt.title(modelName + " data-set:" + str(skip.index(i) + 1) )
        plt.legend()
        plt.savefig("data/images/autogluon/" + modelName + " data-set:" + str(i) + ".png")  
        plt.show()
# Out:
#                     model  score_test  score_val  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       LightGBMXT_BAG_L1   -0.655292  -0.545817        0.276718       0.166318  115.584633                 0.276718                0.166318         115.584633            1       True          3
# 1       LightGBMXT_BAG_L2   -0.658020  -0.543648        0.932862       1.100820  172.630946                 0.290503                0.181577          46.754575            2       True          6
# 2     WeightedEnsemble_L3   -0.658020  -0.543648        0.934228       1.101295  172.632837                 0.001366                0.000475           0.001891            3       True          7
# 3  RandomForestMSE_BAG_L1   -0.678785  -0.388960        0.245468       0.329139   10.238779                 0.245468                0.329139          10.238779            1       True          4
# 4     WeightedEnsemble_L2   -0.679596  -0.378846        0.297358       0.546329   10.617290                 0.002252                0.000399           0.357529            2       True          5
# 5   KNeighborsDist_BAG_L1   -0.791538  -0.468409        0.049638       0.216791    0.020982                 0.049638                0.216791           0.020982            1       True          2
# 6   KNeighborsUnif_BAG_L1   -0.793819  -0.485220        0.070535       0.206995    0.031978                 0.070535                0.206995           0.031978            1       True          1
#                     model  score_test  score_val  pred_time_test  \
# 0       LightGBMXT_BAG_L1   -0.655292  -0.545817        0.276718
# 1       LightGBMXT_BAG_L2   -0.658020  -0.543648        0.932862
# 2     WeightedEnsemble_L3   -0.658020  -0.543648        0.934228
# 3  RandomForestMSE_BAG_L1   -0.678785  -0.388960        0.245468
# 4     WeightedEnsemble_L2   -0.679596  -0.378846        0.297358
# 5   KNeighborsDist_BAG_L1   -0.791538  -0.468409        0.049638
# 6   KNeighborsUnif_BAG_L1   -0.793819  -0.485220        0.070535
#
#    pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0       0.166318  115.584633                 0.276718                0.166318
# 1       1.100820  172.630946                 0.290503                0.181577
# 2       1.101295  172.632837                 0.001366                0.000475
# 3       0.329139   10.238779                 0.245468                0.329139
# 4       0.546329   10.617290                 0.002252                0.000399
# 5       0.216791    0.020982                 0.049638                0.216791
# 6       0.206995    0.031978                 0.070535                0.206995
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0         115.584633            1       True          3
# 1          46.754575            2       True          6
# 2           0.001891            3       True          7
# 3          10.238779            1       True          4
# 4           0.357529            2       True          5
# 5           0.020982            1       True          2
# 6           0.031978            1       True          1
# data 12 model LightGBMXT_BAG_L1
# {'root_mean_squared_error': -0.6552917134687345, 'mean_squared_error': -0.4294072297407901, 'mean_absolute_error': -0.5013112995201251, 'r2': 0.005119729469581058, 'pearsonr': 0.26159508504289763, 'median_absolute_error': -0.37114731839434245, 'name': 'LightGBMXT_BAG_L1'}
# data 12 model LightGBMXT_BAG_L2
# {'root_mean_squared_error': -0.6580204465773782, 'mean_squared_error': -0.43299090811389224, 'mean_absolute_error': -0.5085821284316274, 'r2': -0.0031831836217472986, 'pearsonr': 0.22884150400959433, 'median_absolute_error': -0.4079827599398402, 'name': 'LightGBMXT_BAG_L2'}
# data 12 model WeightedEnsemble_L3
# {'root_mean_squared_error': -0.6580204465773782, 'mean_squared_error': -0.43299090811389224, 'mean_absolute_error': -0.5085821284316274, 'r2': -0.0031831836217472986, 'pearsonr': 0.22884150400959433, 'median_absolute_error': -0.4079827599398402, 'name': 'WeightedEnsemble_L3'}
# data 12 model RandomForestMSE_BAG_L1
# {'root_mean_squared_error': -0.678784966187951, 'mean_squared_error': -0.46074903032277775, 'mean_absolute_error': -0.5324831913287019, 'r2': -0.067495114627806, 'pearsonr': 0.24854368934858834, 'median_absolute_error': -0.4225205744488919, 'name': 'RandomForestMSE_BAG_L1'}
# data 12 model WeightedEnsemble_L2
# {'root_mean_squared_error': -0.6795955065439653, 'mean_squared_error': -0.4618500525147488, 'mean_absolute_error': -0.5306505774976712, 'r2': -0.07004603873979498, 'pearsonr': 0.21505487773528123, 'median_absolute_error': -0.40229712734134027, 'name': 'WeightedEnsemble_L2'}
# data 12 model KNeighborsDist_BAG_L1
# {'root_mean_squared_error': -0.7915381604630692, 'mean_squared_error': -0.6265326594692596, 'mean_absolute_error': -0.6107374084584765, 'r2': -0.4515940547279267, 'pearsonr': 0.07728135570145177, 'median_absolute_error': -0.47160513504167867, 'name': 'KNeighborsDist_BAG_L1'}
# data 12 model KNeighborsUnif_BAG_L1
# {'root_mean_squared_error': -0.7938188993428898, 'mean_squared_error': -0.6301484449539572, 'mean_absolute_error': -0.6135450675963946, 'r2': -0.4599713557886642, 'pearsonr': 0.07211638896794052, 'median_absolute_error': -0.4711911807837136, 'name': 'KNeighborsUnif_BAG_L1'}
#                     model  score_test  score_val  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0  RandomForestMSE_BAG_L1   -0.716574  -0.388960        0.283384       0.329139   10.238779                 0.283384                0.329139          10.238779            1       True          4
# 1       LightGBMXT_BAG_L1   -0.729213  -0.545817        0.470127       0.166318  115.584633                 0.470127                0.166318         115.584633            1       True          3
# 2     WeightedEnsemble_L2   -0.730826  -0.378846        0.460290       0.546329   10.617290                 0.006769                0.000399           0.357529            2       True          5
# 3       LightGBMXT_BAG_L2   -0.733129  -0.543648        1.523378       1.100820  172.630946                 0.417450                0.181577          46.754575            2       True          6
# 4     WeightedEnsemble_L3   -0.733129  -0.543648        1.525684       1.101295  172.632837                 0.002307                0.000475           0.001891            3       True          7
# 5   KNeighborsUnif_BAG_L1   -0.898695  -0.485220        0.182280       0.206995    0.031978                 0.182280                0.206995           0.031978            1       True          1
# 6   KNeighborsDist_BAG_L1   -0.899744  -0.468409        0.170137       0.216791    0.020982                 0.170137                0.216791           0.020982            1       True          2
#                     model  score_test  score_val  pred_time_test  \
# 0  RandomForestMSE_BAG_L1   -0.716574  -0.388960        0.283384
# 1       LightGBMXT_BAG_L1   -0.729213  -0.545817        0.470127
# 2     WeightedEnsemble_L2   -0.730826  -0.378846        0.460290
# 3       LightGBMXT_BAG_L2   -0.733129  -0.543648        1.523378
# 4     WeightedEnsemble_L3   -0.733129  -0.543648        1.525684
# 5   KNeighborsUnif_BAG_L1   -0.898695  -0.485220        0.182280
# 6   KNeighborsDist_BAG_L1   -0.899744  -0.468409        0.170137
#
#    pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0       0.329139   10.238779                 0.283384                0.329139
# 1       0.166318  115.584633                 0.470127                0.166318
# 2       0.546329   10.617290                 0.006769                0.000399
# 3       1.100820  172.630946                 0.417450                0.181577
# 4       1.101295  172.632837                 0.002307                0.000475
# 5       0.206995    0.031978                 0.182280                0.206995
# 6       0.216791    0.020982                 0.170137                0.216791
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0          10.238779            1       True          4
# 1         115.584633            1       True          3
# 2           0.357529            2       True          5
# 3          46.754575            2       True          6
# 4           0.001891            3       True          7
# 5           0.031978            1       True          1
# 6           0.020982            1       True          2
# data 15 model RandomForestMSE_BAG_L1
# {'root_mean_squared_error': -0.7165735742436998, 'mean_squared_error': -0.5134776873043911, 'mean_absolute_error': -0.5012262187674749, 'r2': -0.05858913206050009, 'pearsonr': 0.12963821563650016, 'median_absolute_error': -0.34335094074040023, 'name': 'RandomForestMSE_BAG_L1'}
# data 15 model LightGBMXT_BAG_L1
# {'root_mean_squared_error': -0.7292125625170018, 'mean_squared_error': -0.5317509613326123, 'mean_absolute_error': -0.5290022014479417, 'r2': -0.09626143948828347, 'pearsonr': 0.026132797481592255, 'median_absolute_error': -0.3949813361570481, 'name': 'LightGBMXT_BAG_L1'}
# data 15 model WeightedEnsemble_L2
# {'root_mean_squared_error': -0.7308260724908495, 'mean_squared_error': -0.5341067482324005, 'mean_absolute_error': -0.5135812506251634, 'r2': -0.10111814596497193, 'pearsonr': 0.03765830962710994, 'median_absolute_error': -0.34860537620464527, 'name': 'WeightedEnsemble_L2'}
# data 15 model LightGBMXT_BAG_L2
# {'root_mean_squared_error': -0.7331290566260288, 'mean_squared_error': -0.537478213669371, 'mean_absolute_error': -0.5367875768704016, 'r2': -0.10806878230017625, 'pearsonr': 0.004970574575720952, 'median_absolute_error': -0.38528675051978506, 'name': 'LightGBMXT_BAG_L2'}
# data 15 model WeightedEnsemble_L3
# {'root_mean_squared_error': -0.7331290566260288, 'mean_squared_error': -0.537478213669371, 'mean_absolute_error': -0.5367875768704016, 'r2': -0.10806878230017625, 'pearsonr': 0.004970574575720952, 'median_absolute_error': -0.38528675051978506, 'name': 'WeightedEnsemble_L3'}
# data 15 model KNeighborsUnif_BAG_L1
# {'root_mean_squared_error': -0.8986950650608496, 'mean_squared_error': -0.8076528199647247, 'mean_absolute_error': -0.6738055796580174, 'r2': -0.6650626090123424, 'pearsonr': -0.13084309569921854, 'median_absolute_error': -0.5004965944067932, 'name': 'KNeighborsUnif_BAG_L1'}
# data 15 model KNeighborsDist_BAG_L1
# {'root_mean_squared_error': -0.8997438086388133, 'mean_squared_error': -0.8095389211838776, 'mean_absolute_error': -0.6751266369317133, 'r2': -0.668951008259139, 'pearsonr': -0.13528761033923514, 'median_absolute_error': -0.4958451056578645, 'name': 'KNeighborsDist_BAG_L1'}

# %%
model_res

import json
with open('data/images/autogluon/evaluate-data-11-14.json', 'w') as fp:
    json.dump(model_res, fp)
